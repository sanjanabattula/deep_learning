# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "loss & accuracy/training_history.xlsx"
train_df = pd.read_excel(file)
train_df
# Out:
#      Epoch  Train Loss  Test Loss  Train Accuracy  Test Accuracy
# 0        0    1.807967   1.346671          35.248          51.34
# 1        1    1.507400   1.117615          48.396          60.55
# 2        2    1.351156   0.953405          55.298          65.79
# 3        3    1.292970   0.812025          57.974          72.28
# 4        4    1.193108   0.932141          61.762          67.02
# ..     ...         ...        ...             ...            ...
# 120    120    0.381448   0.185553          91.260          94.85
# 121    121    0.400179   0.191629          90.698          94.81
# 122    122    0.387026   0.166522          90.904          95.04
# 123    123    0.424704   0.194156          90.000          94.92
# 124    124    0.412765   0.170187          90.488          95.02
#
# [125 rows x 5 columns]

# %%
# Function to plot loss over epochs
def plot_loss(train_df):
    plt.figure(figsize=(8, 5))
    plt.plot(train_df['Epoch'], train_df['Train Loss'], label='Train Loss', marker='o')
    plt.plot(train_df['Epoch'], train_df['Test Loss'], label='Test Loss', marker='s')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Test Loss Over Epochs')
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to plot accuracy over epochs
def plot_accuracy(train_df):
    plt.figure(figsize=(8, 5))
    plt.plot(train_df['Epoch'], train_df['Train Accuracy'], label='Train Accuracy', marker='o')
    plt.plot(train_df['Epoch'], train_df['Test Accuracy'], label='Test Accuracy', marker='s')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Test Accuracy Over Epochs')
    plt.legend()
    plt.grid(True)
    plt.show()

# Call the functions to generate the plots
plot_loss(train_df)
plot_accuracy(train_df)

# %%
# Finetuning data
finetune_file = "loss & accuracy/training_history_finetuning.xlsx"
finetune_df = pd.read_excel(finetune_file)
finetune_df
# Out:
#     Epoch  Train Loss  Train Accuracy
# 0       0    0.302804       90.971667
# 1       1    0.309910       90.711667
# 2       2    0.306393       90.705000
# 3       3    0.302021       90.826667
# 4       4    0.307707       90.593333
# 5       5    0.305875       90.493333
# 6       6    0.293518       90.973333
# 7       7    0.299556       90.815000
# 8       8    0.289545       90.968333
# 9       9    0.295956       90.848333
# 10     10    0.295382       90.848333
# 11     11    0.298089       90.811667
# 12     12    0.292558       90.910000
# 13     13    0.277994       91.351667
# 14     14    0.294363       90.865000
# 15     15    0.295119       90.851667
# 16     16    0.286286       91.158333
# 17     17    0.278138       91.368333
# 18     18    0.290865       91.070000
# 19     19    0.280565       91.203333
# 20     20    0.289354       90.998333
# 21     21    0.286513       91.236667
# 22     22    0.294422       90.901667
# 23     23    0.280974       91.131667
# ...

# %%
# Function to plot loss (Finetuning data)
def plot_loss(finetune_df):
    plt.figure(figsize=(8, 5))
    plt.plot(finetune_df['Epoch'], finetune_df['Train Loss'], label='Train Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Finetuning Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to plot accuracy (Finetuning data)
def plot_accuracy(finetune_df):
    plt.figure(figsize=(8, 5))
    plt.plot(finetune_df['Epoch'], finetune_df['Train Accuracy'], label='Train Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Finetuning Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

# Call the functions to generate the plots
plot_loss(finetune_df)
plot_accuracy(finetune_df)
